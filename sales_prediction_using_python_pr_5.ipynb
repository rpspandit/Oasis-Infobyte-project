# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
data=pd.read_csv("/content/Advertising.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.shape
# Out:
# (200, 5)

# %%
# total no of NAN values in dataset
data.isnull().sum().sum()
# Out:
# 0

# %%
#missing values calumns wise
data.isnull().sum(axis=0).sort_values()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %% [markdown]
# # visualization of dataset

# %%
plt.figure(figsize=(5,5))
snr.heatmap(data[4:6].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #we visualization on categorical data

# %%
snr.countplot(x='TV',data=data.iloc[0:5])
# Out:
# <Axes: xlabel='TV', ylabel='count'>

# %%
snr.countplot(data=data.iloc[0:2], x="Sales")
# Out:
# <Axes: xlabel='Sales', ylabel='count'>

# %% [markdown]
# #we analysis the data on numerical value

# %%
data.iloc[0:1].plot(kind='bar')
# Out:
# <Axes: >

# %%
data[1:5].diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.iloc[0:50].plot.scatter(x='Sales',y='TV')
# Out:
# <Axes: xlabel='Sales', ylabel='TV'>

# %%
snr.relplot(x='Sales',y='TV',hue='Newspaper',data=data)

# %%
#Divide the data into dependent and independent set
x=data.drop(columns=['Sales'])
y=data['Sales']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15)

# %% [markdown]
# Creating a regression model with the help of :
#
# 1. Linear Regression
#
# 2. Decision Tree Regression
#
# 3. Random Forest Regression

# %%
#creating the model with Linear Regression
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear_predictions=regression.predict(x_test)

# %%
regression.score(x,y)
# Out:
# 0.89653285339391

# %%
#creating the model with Decision_Tree_Regressor
from sklearn.tree import DecisionTreeRegressor
tree_regressor=DecisionTreeRegressor()
tree_regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
tree_predictions=tree_regressor.predict(x_test)

# %%
tree_regressor.score(x,y)
# Out:
# 0.995781913871204

# %%
#creating the model with Random_Forest_Regressor
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr_predictions=rfr.predict(x_test)

# %%
rfr.score(x,y)
# Out:
# 0.9937369567339276

# %% [markdown]
# #Analysis on top of new dataset

# %%
data_new={'Unnamed: 0':[4],'TV':[300],'Radio':[50],'Newspaper':[40]}
index=[1]

# %%
my_data=pd.DataFrame(data_new,index)

# %%
my_data
# Out:
#    Unnamed: 0   TV  Radio  Newspaper
# 1           4  300     50         40

# %%
new_predictions=tree_regressor.predict(my_data)

# %%
print('the new sales for new data is ',new_predictions)
# Out:
# the new sales for new data is  [25.4]
